# %% [markdown]
# # Linear search and Binary Search

# %%
import time

# Input from the user
n = int(input("Enter the number of elements: "))

# Modified input for array elements to handle space-separated input
print(f"Enter {n} sorted elements separated by spaces:")
arr_input_str = input()
arr = [int(x) for x in arr_input_str.split()]

# Element to search
key = int(input("Enter the element to search: "))

# Start timer
start_time = time.time()

# Linear Search
position = -1
for i in range(n):
    if arr[i] == key:
        position = i
        break

# Stop timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if position != -1:
    print(f"\nElement {key} found at index {position}")
else:
    print(f"\nElement {key} not found")

# Display execution time
print(f"\nExecution Time: {execution_time:.6f} seconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(n)")
print("Worst Case   : O(n)")
print("Space Complexity: O(1)")


###binary search


import time

# Input from the user (This part is repeated for demonstration,
# but ideally, input should be taken once for both algorithms if comparing)
n = int(input("Enter the number of elements for binary search: "))

# Modified input for array elements to handle space-separated input
print(f"Enter {n} sorted elements separated by spaces for binary search:")
arr_input_str_binary = input()
arr_binary = [int(x) for x in arr_input_str_binary.split()]

# Element to search
key_binary = int(input("Enter the element to search for binary search: "))

# Start timer
start_time = time.time()

# Binary Search
low = 0
high = n - 1
position = -1

while low <= high:
    mid = (low + high) // 2

    if arr_binary[mid] == key_binary:
        position = mid
        break
    elif arr_binary[mid] < key_binary:
        low = mid + 1
    else:
        high = mid - 1

# Stop timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

# Display result
if position != -1:
    print(f"\nElement {key_binary} found at index {position}")
else:
    print(f"\nElement {key_binary} not found")

# Display execution time
print(f"\nExecution Time: {execution_time:.6f} seconds")

# Display time complexity
print("\nTime Complexity:")
print("Best Case    : O(1)")
print("Average Case : O(log n)")
print("Worst Case   : O(log n)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter 5 sorted elements separated by spaces:
# 1 2 3 4 5
# Enter the element to search: 3
#
# Element 3 found at index 2
#
# Execution Time: 0.000184 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(n)
# Worst Case   : O(n)
# Space Complexity: O(1)
# Enter the number of elements for binary search: 5
# Enter 5 sorted elements separated by spaces for binary search:
# 2 4 6 8 10
# Enter the element to search for binary search: 8
#
# Element 8 found at index 3
#
# Execution Time: 0.000261 seconds
#
# Time Complexity:
# Best Case    : O(1)
# Average Case : O(log n)
# Worst Case   : O(log n)
# Space Complexity: O(1)
